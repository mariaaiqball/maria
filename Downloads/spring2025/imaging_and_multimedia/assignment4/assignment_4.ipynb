# %% [markdown]
# Creator: Maria Iqbal mi327
# Assignment 4

# %%
# import train.py and other lib for testing
import warnings
import train as t
import test
warnings.filterwarnings("ignore")
import train as t
import numpy as np
import pickle 
from sklearn.metrics import confusion_matrix
from scipy.spatial.distance import cdist

# %% [markdown]
# Let's run our train and test file to see the original model and stats that we will compare to our enhancements. I used a threshold of 220 and found that these values worked best for the images because the letters were bold enough to recognize each letter as a singlular connected component. Letters that have a hole such as a or q were also easy to read. The hole was connected without turning into a completely filled circle.
#
# Each image has:
# - the name of the image being processed
# - the number of connected components recognized for training data
# - the image showing object detection as red boces

# %%
threshold = 200
Features, Labels, normalized_features, mean, std = t.train_data(threshold)
test.test_data(Labels, normalized_features, mean, std, threshold, 'test1')
# Out:
# Processing: r.bmp
# Number of Connected Components: 80
# Processing: s.bmp
# Number of Connected Components: 71
# Processing: d.bmp
# Number of Connected Components: 80
# Processing: f.bmp
# Number of Connected Components: 80
# Processing: q.bmp
# Number of Connected Components: 79
# Processing: p.bmp
# Number of Connected Components: 77
# Processing: u.bmp
# Number of Connected Components: 65
# Processing: w.bmp
# Number of Connected Components: 78
# Processing: a.bmp
# Number of Connected Components: 79
# Processing: m.bmp
# Number of Connected Components: 80
# Processing: z.bmp
# Number of Connected Components: 84
# Processing: x.bmp
# Number of Connected Components: 80
# Processing: o.bmp
# Number of Connected Components: 80
# Processing: n.bmp
# Number of Connected Components: 79
# Processing: k.bmp
# Number of Connected Components: 80
# Processing: h.bmp
# Number of Connected Components: 79
# Processing: test1.bmp
# Processing: test2.bmp
# Number of images read: 16
# ...

# %% [markdown]
# I added image morphology to my bounding_box function with finds the different components of the image and takes the hu's to append the features for each region. I used closing because openimg was creating gaps within the letter. Closing helped to reduce the noise while darkening the letters. As we can see our recognition rate increased by a little more than 10%.

# %%
Features, Labels, normalized_features, mean, std = t.train_data_1(220, 1)
test.test_data_1(Labels, normalized_features, mean, std, 220, 2, 'test1')
# Out:
# Processing: r.bmp
# Number of Connected Components: 80
# Processing: s.bmp
# Number of Connected Components: 73
# Processing: d.bmp
# Number of Connected Components: 80
# Processing: f.bmp
# Number of Connected Components: 80
# Processing: q.bmp
# Number of Connected Components: 80
# Processing: p.bmp
# Number of Connected Components: 80
# Processing: u.bmp
# Number of Connected Components: 64
# Processing: w.bmp
# Number of Connected Components: 80
# Processing: a.bmp
# Number of Connected Components: 80
# Processing: m.bmp
# Number of Connected Components: 80
# Processing: z.bmp
# Number of Connected Components: 83
# Processing: x.bmp
# Number of Connected Components: 79
# Processing: o.bmp
# Number of Connected Components: 79
# Processing: n.bmp
# Number of Connected Components: 80
# Processing: k.bmp
# Number of Connected Components: 80
# Processing: h.bmp
# Number of Connected Components: 80
# Processing: test1.bmp
# Processing: test2.bmp
# Number of images read: 16
# ...
